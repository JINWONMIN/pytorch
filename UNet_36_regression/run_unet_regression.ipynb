# %% [markdown]
# ### Inpainting
#
# - **random** sampling
# - probability 50%
#
# ### Larning type
#
# - plain
# - residual
#
# ### Network
#
# - UNet

# %%
# !python3 '/content/drive/MyDrive/pytorch/UNet_36_regression/train.py' \
--mode 'train' \
--data_dir '/content/drive/MyDrive/pytorch/UNet_36_regression/datasets/BSR/BSR/BSDS500/data/images' \
--ckpt_dir '/content/drive/MyDrive/pytorch/UNet_36_regression/checkpoint/inpainting/plain' \
--log_dir '/content/drive/MyDrive/pytorch/UNet_36_regression/log/inpainting/plain' \
--result_dir '/content/drive/MyDrive/pytorch/UNet_36_regression/results/inpainting/plain' \
--network "unet" \
--task 'inpainting' \
--opts 'random' 0.5 \
--learning_type 'plain'
# Out:
# /content/drive/MyDrive/pytorch/UNet_36_regression/train.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   opts = [args.opts[0], np.asarray(args.opts[1:]).astype(np.float)]   # 옵션은 두 가지 타입으로 나누어서 저장을 한다. 옵션의 첫 번째 인자는 항상 타입을 설정하는 값을 따로 떼서 받고, 그 외에 변수들은 항상 숫자로 받기 때문에 array형태로 받도록 설정한다.
# mode: train
# learning rate: 1.0000e-03
# batch size: 4
# number of epoch: 100
# data dir: /content/drive/MyDrive/pytorch/UNet_36_regression/datasets/BSR/BSR/BSDS500/data/images
# ckpt dir: /content/drive/MyDrive/pytorch/UNet_36_regression/checkpoint/inpainting/plain
# log dir: /content/drive/MyDrive/pytorch/UNet_36_regression/log/inpainting/plain
# ...

# %%
# !python3 '/content/drive/MyDrive/pytorch/UNet_36_regression/train.py' \
--mode 'train' \
--data_dir '/content/drive/MyDrive/pytorch/UNet_36_regression/datasets/BSR/BSR/BSDS500/data/images' \
--ckpt_dir '/content/drive/MyDrive/pytorch/UNet_36_regression/checkpoint/inpainting/residual' \
--log_dir '/content/drive/MyDrive/pytorch/UNet_36_regression/log/inpainting/residual' \
--result_dir '/content/drive/MyDrive/pytorch/UNet_36_regression/results/inpainting/residual' \
--network "unet" \
--task 'inpainting' \
--opts 'random' 0.5 \
--learning_type 'residual'

# %% [markdown]
# ### Denoising
#
# - **random** noise
# - sigma **30.0**
#
# ### Larning type
#
# - plain
# - residual
#
# ### Network
#
# - UNet

# %%
# !python3 '/content/drive/MyDrive/pytorch/UNet_36_regression/train.py' \
--mode 'train' \
--data_dir '/content/drive/MyDrive/pytorch/UNet_36_regression/datasets/BSR/BSR/BSDS500/data/images' \
--ckpt_dir '/content/drive/MyDrive/pytorch/UNet_36_regression/checkpoint/denoising/plain' \
--log_dir '/content/drive/MyDrive/pytorch/UNet_36_regression/log/denoising/plain' \
--result_dir '/content/drive/MyDrive/pytorch/UNet_36_regression/results/denoising/plain' \
--network "unet" \
--task 'denoising' \
--opts 'random' 30.0 \
--learning_type 'plain'

# %%
# !python3 '/content/drive/MyDrive/pytorch/UNet_36_regression/train.py' \
--mode 'train' \
--data_dir '/content/drive/MyDrive/pytorch/UNet_36_regression/datasets/BSR/BSR/BSDS500/data/images' \
--ckpt_dir '/content/drive/MyDrive/pytorch/UNet_36_regression/checkpoint/denoising/residual' \
--log_dir '/content/drive/MyDrive/pytorch/UNet_36_regression/log/denoising/residual' \
--result_dir '/content/drive/MyDrive/pytorch/UNet_36_regression/results/denoising/residual' \
--network "unet" \
--task 'denoising' \
--opts 'random' 30.0 \
--learning_type 'residual'

# %% [markdown]
# ### Super resolution
#
# - **bilinear** interpolation
# - **x4** downsampling
#
# ### Larning type
#
# - plain
# - residual
#
# ### Network
#
# - UNet

# %%
# !python3 '/content/drive/MyDrive/pytorch/UNet_36_regression/train.py' \
--mode 'train' \
--data_dir '/content/drive/MyDrive/pytorch/UNet_36_regression/datasets/BSR/BSR/BSDS500/data/images' \
--ckpt_dir '/content/drive/MyDrive/pytorch/UNet_36_regression/checkpoint/super_resolution/plain' \
--log_dir '/content/drive/MyDrive/pytorch/UNet_36_regression/log/super_resolution/plain' \
--result_dir '/content/drive/MyDrive/pytorch/UNet_36_regression/results/super_resolution/plain' \
--network "unet" \
--task 'super_resolution' \
--opts 'bilinear' 4.0 \
--learning_type 'plain'

# %%
# !python3 '/content/drive/MyDrive/pytorch/UNet_36_regression/train.py' \
--mode 'train' \
--data_dir '/content/drive/MyDrive/pytorch/UNet_36_regression/datasets/BSR/BSR/BSDS500/data/images' \
--ckpt_dir '/content/drive/MyDrive/pytorch/UNet_36_regression/checkpoint/super_resolution/residual' \
--log_dir '/content/drive/MyDrive/pytorch/UNet_36_regression/log/super_resolution/residual' \
--result_dir '/content/drive/MyDrive/pytorch/UNet_36_regression/results/super_resolution/residual' \
--network "unet" \
--task 'super_resolution' \
--opts 'bilinear' 4.0 \
--learning_type 'residual'
